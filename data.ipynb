# %%
import pandas as pd

# %%
# Cargamos dataset
movies = pd.read_csv('../limpios/movieslimpio.csv')
credits = pd.read_csv('../limpios/creditslimpio.csv')

# Unimos datasets
df = pd.merge(movies, credits, on=['id', 'id'], how='inner')

# %%
df.head()
# Out:
#    belongs_to_collection      budget                              genres  \
# 0                      1  30000000.0   ['Animation', 'Comedy', 'Family']
# 1                      0  65000000.0  ['Adventure', 'Fantasy', 'Family']
# 2                      1         0.0               ['Romance', 'Comedy']
# 3                      0  16000000.0      ['Comedy', 'Drama', 'Romance']
# 4                      1         0.0                          ['Comedy']
#
#         id original_language  popularity  \
# 0    862.0                en   21.946943
# 1   8844.0                en   17.015540
# 2  15602.0                en   11.712900
# 3  31357.0                en    3.859495
# 4  11862.0                en    8.387519
#
#                                 production_companies production_countries  \
# 0                        ['Pixar Animation Studios']               ['US']
# 1  ['TriStar Pictures', 'Teitler Film', 'Intersco...               ['US']
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45451 entries, 0 to 45450
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  45451 non-null  int64
#  1   budget                 45451 non-null  float64
#  2   genres                 43067 non-null  object
#  3   id                     45451 non-null  float64
#  4   original_language      45451 non-null  object
#  5   popularity             45451 non-null  float64
#  6   production_companies   33634 non-null  object
#  7   production_countries   39232 non-null  object
#  8   release_date           45451 non-null  object
#  9   revenue                45451 non-null  float64
#  10  runtime                45451 non-null  float64
#  11  status                 45451 non-null  object
#  12  title                  45451 non-null  object
#  13  vote_average           45451 non-null  float64
# ...

# %%
# Revisamos en el dataframe final la cantidad de peliculas de las que se tiene informacion
df.id.unique().size
# Out:
# 45345

# %%
df.describe()
# Out:
#        belongs_to_collection        budget             id    popularity  \
# count           45451.000000  4.545100e+04   45451.000000  45451.000000
# mean                0.098942  4.231294e+06  107984.599745      2.926887
# std                 0.298587  1.742942e+07  112111.336735      6.006458
# min                 0.000000  0.000000e+00       2.000000      0.000000
# 25%                 0.000000  0.000000e+00   26367.500000      0.389095
# 50%                 0.000000  0.000000e+00   59871.000000      1.131386
# 75%                 0.000000  0.000000e+00  156327.500000      3.694370
# max                 1.000000  3.800000e+08  469172.000000    547.488300
#
#             revenue       runtime  vote_average    vote_count  release_year  \
# count  4.545100e+04  45451.000000  45451.000000  45451.000000  45451.000000
# mean   1.121930e+07     97.492611      5.624085    109.989703   1991.882027
# std    6.433984e+07     33.927735      1.915424    491.352336     24.057726
# ...

# %%
df['actor_name'] = df['actor_name'].astype(str)

# %%
invalid_actor_count = df[~df['actor_name'].explode().str.isalpha()].shape[0]

# %%
invalid_actor_count
# Out:
# 45451

# %%
df.to_csv('../limpios/dfinal.csv', index=False)
